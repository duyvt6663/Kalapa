# %%
import os
import re
import html
import time
import random
import json
import requests
import math

from tqdm.auto import tqdm
from bs4 import BeautifulSoup
from googletrans import Translator

# %%
dataset_dir = "../datasets"
kalapa_dataset_dir = os.path.join(dataset_dir, "KALAPA_ByteBattles_2023_MEDICAL_Set1")
processed_save_dir = os.path.join(kalapa_dataset_dir, "translated")
subsection_save_dir = os.path.join(kalapa_dataset_dir, "translated_subsections")

os.makedirs(subsection_save_dir, exist_ok=True)

# %%
# def name_formatter(text):
#     # format the text so that we can use it as filename by replacing all special characters with _
#     text = text.lower()
#     text = re.sub(r"\s+", "_", text)
#     text = re.sub(r"[^a-zA-Z0-9_]", "", text)
#     return text
from pyvi import ViUtils
ViUtils.remove_accents(u"Trường đại học bách khoa hà nội")

def get_document_name_with_accent(document):
    name = document["name"]
    title = document["title"]
    title = title.replace("(", "").replace(")", "")
    
    name_no_accent = name.replace("-", " ").lower()
    title_no_accent = ViUtils.remove_accents(title).decode('ASCII').lower()
    # print(name_no_accent)
    # print(title_no_accent)
    
    # find start index of title in name
    start_index = title_no_accent.find(name_no_accent)
    if start_index == -1:
        print(f"Cannot find title {title} in name {name}")
        return name_no_accent
    else:
        return title[start_index:start_index+len(name_no_accent)]

def get_subsection_sample_from_document(document):
    subsec_2_save = []

    name = document["name"]
    title = document["title"]
    abstract = document["abstract"]
    category = document["category"]
    subsections = document["subsections"]
    document_name_with_accent = get_document_name_with_accent(document)
    for i, subsection in enumerate(subsections):
        subsection_name = subsection['subsection_name']
        subsection_content = subsection['subsection_content']
        
        subsection_title = document_name_with_accent + ". " + subsection_name
        subsection_data = subsection_title + "\n" + subsection_content
        
        subsec = {
            "document_name": name,
            "document_name_accent": document_name_with_accent,
            "document_title": title,
            "document_category": category,
            "subsection_name": subsection_name,
            "subsection_content": subsection_content,
            
            "subsection_name": f"{name}_{i}_{subsection_name}",
            "subsection_title": subsection_title,
            "subsection_data": subsection_data,
        }
        # print(json.dumps(subsec, indent=4, ensure_ascii=False))
        subsec_2_save.append(subsec)
    
    return subsec_2_save

# %%
filenames = os.listdir(processed_save_dir)
filenames = sorted(filenames)
num_subsections = 0

for i, filename in enumerate(filenames):
    processed_filepath = os.path.join(processed_save_dir, filename)
    with open(
        processed_filepath, "r", encoding="utf-8"
    ) as f:
        document = json.load(f)
    
    subsec_2_save = get_subsection_sample_from_document(document)
    for i, subsection in enumerate(subsec_2_save):
        subsection_save_path = os.path.join(subsection_save_dir, f"{subsection['document_name'].split('.')[0]}_{i}.json")
        with open(subsection_save_path, "w", encoding="utf-8") as f:
            json.dump(subsection, f, indent=4, ensure_ascii=False)
    num_subsections += len(subsec_2_save)
print(f"num_subsections: {num_subsections}")
# Out:
# Cannot find title Alzheimer's disease: Causes, symptoms, treatment and prevention in name alzheimer.json
# Cannot find title What disease is indigestion? Causes, symptoms and prevention in name an-khong-tieu.json
# Cannot find title Anal abscess: Causes, symptoms and prevention in name ap-xe-hau-mon.json
# Cannot find title Lung abscess: Causes, symptoms and treatments in name ap-xe-phoi.json
# Cannot find title Diabetic feet: Causes, symptoms and diagnosis in name ban-chan-dai-thao-duong.json
# Cannot find title Postpartum hemorrhage: Causes, symptoms and prevention in name bang-huyet-sau-sinh.json
# Cannot find title Overactive bladder: Causes, symptoms, diagnosis and treatment in name bang-quang-tang-hoat.json
# Cannot find title Postpartum dyshidrosis: Causes, signs, treatment and prevention in name be-san-dich.json
# Cannot find title Diphtheria: unpredictable complications and effective prevention in name benh-bach-hau.json
# Cannot find title Basedow's disease: Causes, causes and diagnosis in name benh-basedow.json
# Cannot find title Eczema: Signs, causes, complications and diagnosis in name benh-cham.json
# Cannot find title Chlamydia: Causes, symptoms, treatment, prevention in name benh-chlamydia.json
# Cannot find title Dilated cardiomyopathy: Causes, signs, treatment and prevention in name benh-co-tim-gian-no.json
# Cannot find title Hypertrophic cardiomyopathy: Causes, signs, diagnosis and treatment in name benh-co-tim-phi-dai.json
# Cannot find title Crohn's disease chronic regional enteritis symptoms and causes in name benh-crohn.json
# Cannot find title Influenza: Symptoms, causes and diagnosis in name benh-cum.json
# Cannot find title Glaucoma: The silent thief of sight in name benh-cuom-nuoc-glaucoma.json
# Cannot find title Rabies: Symptoms, causes, diagnosis and prevention in name benh-dai.json
# Cannot find title Trigeminal neuralgia: treatment and prevention in name benh-dau-day-than-kinh-sinh-ba.json
# Cannot find title Monkeypox: Causes, symptoms, treatment and prevention in name benh-dau-mua-khi.json
# Cannot find title Smallpox: Symptoms, causes, diagnosis and prevention in name benh-dau-mua.json
# Cannot find title Epilepsy: Signs of recognition and treatment in name benh-dong-kinh.json
# Cannot find title Keratoconus: Causes, signs and treatments in name benh-giac-mac-hinh-chop.json
# Cannot find title Syphilis: Causes, signs and prevention in name benh-giang-mai.json
# Cannot find title Gnathostomiasis: Causes, symptoms, treatment and prevention in name benh-giun-dau-gai.json
# Cannot find title Ascariasis: Causes, symptoms, diagnosis, prevention in name benh-giun-dua.json
# Cannot find title What is strongyloidiasis? Causes, symptoms and treatment in name benh-giun-luon.json
# Cannot find title Dragon worm disease: Causes, signs, treatment measures in name benh-giun-rong.json
# Cannot find title Acute gout: Causes, symptoms, diagnosis and treatment in name benh-gout-cap-tinh.json
# Cannot find title Gout: Causes, symptoms, diagnosis in name benh-gout.json
# Cannot find title Heart valve regurgitation: Causes, signs, treatment and prevention in name benh-ho-van-tim.json
# Cannot find title What is cough? Causes, symptoms and prevention in name benh-ho.json
# Cannot find title Pulmonary tuberculosis tuberculosis: Causes, signs and treatments in name benh-lao-phoi.json
# Cannot find title What is gonorrhea? Causes and warning signs in name benh-lau.json
# Cannot find title Peritoneal duct disease: Causes, diagnosis and treatment in name benh-ly-ong-phuc-tinh-mac.json
# Cannot find title Coronary artery disease: Causes, signs and treatments in name benh-mach-vanh.json
# Cannot find title Moyamoya disease: Warning symptoms and treatment in name benh-moyamoya.json
# Cannot find title Color blindness: causes, symptoms, diagnosis and treatment in name benh-mu-mau.json
# Cannot find title What is dog tapeworm infection? Is it dangerous? Causes and symptoms in name benh-nhiem-san-cho.json
# Cannot find title What is myasthenia gravis? Causes, symptoms, prevention in name benh-nhuoc-co.json
# Cannot find title Parkinson's disease: Causes, symptoms and diagnosis in name benh-parkinson.json
# Cannot find title Chronic obstructive pulmonary disease COPD: Causes and symptoms in name benh-phoi-tac-nghen-man-tinh-copd.json
# Cannot find title Nasal polyps: 7 causes, symptoms and prevention in name benh-polyp-mui.json
# Cannot find title Mumps: Causes, signs and diagnosis in name benh-quai-bi.json
# Cannot find title Pubic lice: Causes, signs, treatment, prevention in name benh-ran-mu.json
# Cannot find title Rubella German measles: Causes, symptoms, diagnosis and treatment in name benh-rubella.json
# Cannot find title Pork tapeworm disease: Signs, causes, treatment, prevention in name benh-san-day-lon.json
# Cannot find title How does tapeworm infect people? Signs and causes in name benh-san-day.json
# Cannot find title Fascioliasis: Causes, symptoms, diagnosis in name benh-san-la-gan.json
# Cannot find title Retinal vein occlusion: Causes, signs and treatments in name benh-tac-tinh-mach-vong-mac.json
# Cannot find title Hand, foot and mouth disease: Causes, symptoms and care in name benh-tay-chan-mieng.json
# Cannot find title Diabetic neuropathy: Signs, causes and treatment in name benh-than-kinh-dai-thao-duong.json
# Cannot find title Peripheral neuropathy: Causes, symptoms and treatments in name benh-than-kinh-ngoai-bien.json
# Cannot find title Dangerous neurological diseases: Causes and symptoms in name benh-than-kinh.json
# Cannot find title Inguinal hernia – causes and treatments in name benh-thoat-vi-ben.json
# Cannot find title Chickenpox: Signs, causes and diagnosis in name benh-thuy-dau.json
# Cannot find title Acyanotic congenital heart disease: Causes, symptoms, treatment in name benh-tim-bam-sinh-khong-tim.json
# Cannot find title Cyanotic congenital heart disease: Causes, symptoms, treatment and prevention in name benh-tim-bam-sinh-tim.json
# Cannot find title Congenital heart disease: Signs of recognition, screening and treatment in name benh-tim-bam-sinh.json
# Cannot find title Thrombosed hemorrhoids: Causes, symptoms and treatments in name benh-tri-huyet-khoi.json
# Cannot find title External hemorrhoids: Symptoms, treatment, is it dangerous? in name benh-tri-ngoai.json
# Cannot find title Internal hemorrhoids: Signs, causes, treatment, what to eat and what to avoid? in name benh-tri-noi.json
# Cannot find title Postpartum hemorrhoids: Causes, signs, treatment and prevention in name benh-tri-sau-sinh.json
# Cannot find title Hemorrhoids: Signs, causes, prevention, is it contagious and dangerous? in name benh-tri.json
# Cannot find title Autoimmune disease: Causes, symptoms and treatment in name benh-tu-mien.json
# Cannot find title Colon diverticulosis: Causes, prevention, treatment in name benh-tui-thua-dai-trang.json
# Cannot find title Heart valve disease: Causes, symptoms and treatments in name benh-van-tim.json
# Cannot find title Myocarditis: Causes, signs and treatments in name benh-viem-co-tim-nguyen-nhan-dau-hieu-va-cach-dieu-tri-benh.json
# Cannot find title Hepatitis B: Causes, symptoms, diagnosis and prevention in name benh-viem-gan-b.json
# Cannot find title Hepatitis: Symptoms, causes and diagnosis in name benh-viem-gan.json
# Cannot find title Acute pharyngitis: Causes, symptoms and prevention in name benh-viem-hong-cap.json
# Cannot find title Sore throat: Causes, symptoms and prevention in name benh-viem-hong.json
# Cannot find title Gastric ulcer disease: Causes and symptoms in name benh-viem-loet-da-day.json
# Cannot find title Acute pancreatitis: causes, symptoms, complications and diagnosis in name benh-viem-tuy-cap.json
# Cannot find title Sinusitis: Causes, signs and prevention in name benh-viem-xoang.json
# Cannot find title Diabetic retinopathy: symptoms, diagnosis, prevention in name benh-vong-mac-tieu-duong.json
# Cannot find title Whitmore disease bacterial infection: Causes, symptoms, prevention in name benh-whitmore.json
# Cannot find title Otosclerosis: Causes, signs, complications, treatment, prevention in name benh-xop-xo-tai.json
# Cannot find title Obesity level 1: Causes, symptoms and treatment in name beo-phi-do-1.json
# Cannot find title Obesity: Causes, causes and diagnosis in name beo-phi.json
# Cannot find title Silicosis: Causes, symptoms and treatment in name bui-phoi-silic.json
# Cannot find title Pneumoconiosis dust in the lungs: Causes, signs and treatments in name bui-phoi.json
# Cannot find title Polycystic ovary syndrome: Causes, signs, diagnosis and treatment in name buong-trung-da-nang.json
# Cannot find title Malignant goiter: Symptoms, diagnosis and prevention in name buou-co-ac-tinh.json
# Cannot find title Benign goiter: Causes, diagnosis, treatment and prevention in name buou-co-lanh-tinh.json
# Cannot find title Bilobed multinodular goiter: Signs, causes and diagnosis in name buou-giap-da-nhan-2-thuy.json
# Cannot find title Multinodular goiter: Causes, signs and diagnosis in name buou-giap-da-nhan.json
# Cannot find title Colloid goiter: Causes, symptoms, diagnosis and treatment in name buou-giap-keo.json
# Cannot find title Diffuse goiter: Classification, causes and prevention in name buou-giap-lan-toa.json
# Cannot find title Right lobe goiter: Causes, diagnosis and treatment in name buou-giap-nhan-thuy-phai.json
# Cannot find title Nummular eczema: Causes, signs, diagnosis, prevention in name cham-dong-tien.json
# Cannot find title Delayed menstruation late menstruation: Causes, signs, diagnosis and prevention in name cham-kinh.json
# Cannot find title Traumatic brain injury: Signs, causes and diagnosis in name chan-thuong-so-nao.json
# Cannot find title Benign paroxysmal vertigo: Causes, diagnosis and treatment in name chong-mat-kich-phat-lanh-tinh.json
# Cannot find title What is dizziness? Causes, symptoms and treatments in name chong-mat.json
# Cannot find title Abdominal bloating: Causes, symptoms and prevention in name chuong-bung-day-hoi.json
# Cannot find title Delayed labor: Causes, signs of recognition and treatment in name chuyen-da-dinh-tre.json
# Cannot find title Prolonged labor: Causes, signs, treatment and prevention in name chuyen-da-keo-dai.json
# Cannot find title Rickets: Causes, symptoms and diagnosis in name coi-xuong.json
# Cannot find title Is false labor dangerous? Causes, signs, prevention in name con-go-chuyen-da-gia.json
# Cannot find title Patent ductus arteriosus: Causes, symptoms, diagnosis, treatment in name con-ong-dong-mach.json
# Cannot find title Influenza A H5N1: Symptoms, causes, treatment and prevention in name cum-a-h5n1.json
# Cannot find title Joint stiffness: Causes, symptoms, treatment and prevention in name cung-khop.json
# Cannot find title Hyperthyroidism: Causes, signs, treatment and prevention in name cuong-giap.json
# Cannot find title Gestational diabetes: Causes, signs and treatments in name dai-thao-duong-thai-ky.json
# Cannot find title Diabetes: Causes, signs, treatment and prevention in name dai-thao-duong.json
# Cannot find title Proteinuria: Causes, symptoms, diagnosis, treatment in name dam-nieu.json
# Cannot find title Dysmenorrhea: Causes, symptoms, diagnosis and prevention in name dau-bung-kinh.json
# Cannot find title Postpartum wrist pain: Causes, symptoms and treatments in name dau-co-tay-sau-sinh.json
# Cannot find title Stomach pain stomach pain: Causes, symptoms, and diagnosis in name dau-da-day.json
# Cannot find title Knee pain when standing up and sitting down: Causes and treatments in name dau-dau-goi-khi-dung-len-ngoi-xuong.json
# Cannot find title Migraine headaches: Causes, symptoms, diagnosis and prevention in name dau-dau-migraine.json
# Cannot find title What is a headache at the back of the neck? Causes, symptoms and treatment in name dau-dau-sau-gay.json
# Cannot find title What is a vasomotor headache? Symptoms, causes and treatments in name dau-dau-van-mach.json
# Cannot find title Headache: Causes, symptoms, diagnosis and treatment in name dau-dau.json
# Cannot find title What is a headache? Causes and symptoms should be noted in name dau-dinh-dau.json
# Cannot find title Embryo transfer failure: Causes, signs and ways to improve in name dau-hieu-chuyen-phoi-that-bai.json
# Cannot find title Eye socket pain: 17 common causes and dangerous signs in name dau-hoc-mat.json
# Cannot find title Sore throat: Causes, symptoms and prevention in name dau-hong.json
# Cannot find title Knee pain: Causes, symptoms, treatment and prevention in name dau-khop-goi.json
# Cannot find title Elbow pain: Causes, diagnosis and treatment in name dau-khop-khuyu-tay.json
# Cannot find title Joint pain: Causes, treatment and prevention in name dau-khop.json
# Cannot find title Sore eyes: Causes, symptoms and common diseases in name dau-mat.json
# Cannot find title Right-sided migraine: Causes, symptoms and prevention in name dau-nua-dau-ben-phai.json
# Cannot find title Left-sided migraine: Causes, symptoms and prevention in name dau-nua-dau-ben-trai.json
# Cannot find title What is frontal migraine? The cause and how to fix it in name dau-nua-dau-phia-truoc.json
# Cannot find title What is posterior migraine? Causes, diagnosis and treatment in name dau-nua-dau-sau.json
# Cannot find title Migraine: Causes, symptoms, diagnosis and precautions in name dau-nua-dau.json
# Cannot find title Angina: A warning sign of a potential heart attack in name dau-that-nguc.json
# Cannot find title Right testicular pain: Causes, symptoms and prevention in name dau-tinh-hoan-ben-phai.json
# Cannot find title Left testicular pain: Causes, symptoms and prevention in name dau-tinh-hoan-ben-trai.json
# Cannot find title Testicular pain: 12 causes, symptoms, and prevention in name dau-tinh-hoan.json
# Cannot find title Breast pain: Causes, symptoms, care and prevention in name dau-vu.json
# Cannot find title Umbilical cord membrane adhesion: Causes, signs, diagnosis, treatment in name day-ron-bam-mang.json
# Cannot find title Precocious puberty: Causes, symptoms, diagnosis and treatment in name day-thi-som.json
# Cannot find title Blood in the urine hematuria: Causes, symptoms and diagnosis in name di-tieu-ra-mau.json
# Cannot find title Eye allergies: Causes, symptoms and prevention in name di-ung-mat.json
# Cannot find title Foreign bodies in the eye: Causes, signs and dangerous complications in name di-vat-trong-mat.json
# Cannot find title Dehydrated disc: Causes, symptoms, diagnosis, treatment in name dia-dem-mat-nuoc.json
# Cannot find title Perimenopause: Causes, signs and treatments in name dieu-tri-chung-roi-loan-tien-man-kinh-luu-y-ve-an-uong.json
# Cannot find title What is the carotid artery? Causes, symptoms, diagnosis, treatment in name dong-mach-canh.json
# Cannot find title What is an ischemic stroke? Causes, symptoms and diagnosis in name dot-quy-thieu-mau-cuc-bo.json
# Cannot find title What is a stroke? Causes and diagnosis of the disease in name dot-quy.json
# Cannot find title Cataracts dry cataracts: Causes, signs and treatments in name duc-thuy-tinh-the.json
# Cannot find title Curved penis: Causes, symptoms, diagnosis, prevention in name duong-vat-cong.json
# Cannot find title Spinal spurs: Causes, signs and treatments in name gai-cot-song.json
# Cannot find title Bone spurs: Causes, symptoms and treatments in name gai-xuong.json
# Cannot find title Grade 1 fatty liver: Causes, signs and treatments in name gan-nhiem-mo-do-1.json
# Cannot find title Grade 2 fatty liver: Causes, symptoms and treatment in name gan-nhiem-mo-do-2.json
# Cannot find title Grade 3 fatty liver: Causes, signs and treatments in name gan-nhiem-mo-do-3.json
# Cannot find title Fatty liver: Causes, symptoms and prevention in name gan-nhiem-mo.json
# Cannot find title What is hepatomegaly? Causes, symptoms, diagnosis and prevention in name gan-to.json
# Cannot find title Bronchiectasis: Causes, symptoms, treatment and prevention in name gian-phe-quan.json
# Cannot find title Varicocele: Causes, symptoms, treatment in name gian-tinh-mach-thung-tinh.json
# Cannot find title Trichinosis: Symptoms, causes, treatment, prevention in name giun-xoan.json
# Cannot find title Hypoglycemia: Causes, symptoms, complications and prevention in name ha-duong-huyet.json
# Cannot find title Tophi Tophi: Causes, symptoms and treatment in name hat-tophi.json
# Cannot find title Vocal cord nodules: Symptoms and treatments in name hat-xo-day-thanh-quan.json
# Cannot find title Swollen anus: Causes, diagnosis and prevention in name hau-mon-bi-sung.json
# Cannot find title Asthma: Causes, symptoms, diagnosis and prevention in name hen-suyen.json
# Cannot find title Phimosis: Symptoms and treatment in name hep-bao-quy-dau.json
# Cannot find title Carotid artery stenosis: Causes, symptoms, treatment and prevention in name hep-dong-mach-canh.json
# Cannot find title Knee joint space stenosis: Causes, signs, diagnosis and treatment in name hep-khe-khop-goi.json
# Cannot find title Coronary artery stenosis: Causes, symptoms, diagnosis and prevention in name hep-mach-vanh.json
# Cannot find title Aortic valve stenosis: Symptoms, causes and treatments in name hep-van-dong-mach-chu.json
# Cannot find title Pulmonary valve stenosis: Causes, signs and treatments in name hep-van-dong-mach-phoi.json
# Cannot find title Mitral valve stenosis: Causes, signs, complications and prevention in name hep-van-hai-la.json
# Cannot find title Genital herpes: Causes, symptoms, diagnosis, prevention in name herpes-sinh-duc.json
# Cannot find title What is Herpes? Common causes and symptoms in name herpes.json
# Cannot find title What is infertility? Causes, signs, diagnosis, prevention in name hiem-muon.json
# Cannot find title Mitral valve regurgitation: Causes, signs and treatments in name ho-van-2-la.json
# Cannot find title Tricuspid valve regurgitation: Causes, symptoms and treatment in name ho-van-3-la.json
# Cannot find title Brugada syndrome: Causes, diagnosis and treatment in name hoi-chung-brugada.json
# Cannot find title Fournier syndrome: Causes, symptoms, treatment and prevention in name hoi-chung-fournier.json
# Cannot find title HELLP syndrome: Causes, signs and prevention in name hoi-chung-hellp.json
# Cannot find title Kallmann syndrome: Signs, causes, diagnosis and treatment in name hoi-chung-kallmann.json
# Cannot find title Klinefelter syndrome: Causes, signs, diagnosis and treatment in name hoi-chung-klinefelter.json
# Cannot find title Thoracic outlet syndrome in name hoi-chung-loi-thoat-long-nguc.json
# Cannot find title Dead butt syndrome DBS: Office workers' nightmare and how to treat it in name hoi-chung-mong-chet.json
# Cannot find title Carpal tunnel syndrome: Causes, symptoms and treatments in name hoi-chung-ong-co-tay.json
# Cannot find title Irritable bowel syndrome: Causes, symptoms and prevention in name hoi-chung-ruot-kich-thich.json
# Cannot find title Stevens Johnson syndrome SJS: Causes, signs, treatment in name hoi-chung-stevens-johnson.json
# Cannot find title Sudeck syndrome: Causes, symptoms, diagnosis, treatment in name hoi-chung-sudeck.json
# Cannot find title What is immunodeficiency syndrome? Causes and symptoms in name hoi-chung-suy-giam-mien-dich.json
# Cannot find title Swyer syndrome – pathophysiology, diagnosis & treatment in name hoi-chung-swyer.json
# Cannot find title Nephrotic syndrome: Causes, symptoms and treatment in name hoi-chung-than-hu.json
# Cannot find title What is HPV virus? Causes, signs, diagnosis and prevention in name hpv.json
# Cannot find title Insulinoma: Causes, symptoms, treatment in name insulinoma.json
# Cannot find title Hoarseness hoarseness: Causes, symptoms and treatments in name khan-tieng.json
# Cannot find title Emphysema: Causes, signs, diagnosis and treatment in name khi-phe-thung.json
# Cannot find title Vaginal private area dryness: Causes, symptoms and diagnosis in name kho-am-dao.json
# Cannot find title Dry joints: Causes, treatment and prevention in name kho-khop.json
# Cannot find title Difficulty breathing, shortness of breath: Causes, symptoms and treatments in name kho-tho.json
# Cannot find title No sperm: Causes, diagnosis and treatment in name khong-co-tinh-trung.json
# Cannot find title Deviated nasal septum: Causes, signs and treatments in name lech-vach-ngan-mui.json
# Cannot find title Stye: Causes, signs, diagnosis and prevention in name leo-mat.json
# Cannot find title Vocal cord paralysis: Causes, symptoms and prevention in name liet-day-thanh-quan.json
# Cannot find title Facial paralysis VII nerve palsy, Bell's palsy diagnosis and treatment in name liet-mat.json
# Cannot find title Hypospadias: Causes, signs, diagnosis, treatment in name lo-tieu-lech-thap.json
# Cannot find title Osteoporosis: Causes, symptoms, diagnosis, classification in name loang-xuong.json
# Cannot find title Congenital pectus excavatum in children: Causes, symptoms, diagnosis in name lom-nguc-bam-sinh.json
# Cannot find title Discoid lupus erythematosus: Causes, symptoms, diagnosis, treatment in name lupus-ban-do-dang-dia.json
# Cannot find title Systemic lupus erythematosus: Causes, symptoms, treatment and prevention in name lupus-ban-do-he-thong.json
# Cannot find title Amoebic dysentery: Symptoms, causes, diagnosis, treatment and prevention in name ly-amip.json
# Cannot find title Ectopic pregnancy: Causes, symptoms, treatment and prevention in name mang-thai-ngoai-tu-cung.json
# Cannot find title Hormonal imbalance: Causes, symptoms and diagnosis in name mat-can-bang-noi-tiet-to.json
# Cannot find title Myopia: Causes, signs, diagnosis and prevention in name mat-can-thi.json
# Cannot find title Eye astigmatism: Causes, signs, diagnosis and prevention in name mat-loan-thi.json
# Cannot find title Prolonged insomnia: Causes, symptoms, treatments, harms in name mat-ngu-keo-dai.json
# Cannot find title Postpartum insomnia: Causes, signs, treatment & prevention in name mat-ngu-sau-sinh.json
# Cannot find title Insomnia: Causes, symptoms and diagnosis in name mat-ngu.json
# Cannot find title Farsighted eyes: Causes, signs, diagnosis and prevention in name mat-vien-thi.json
# Cannot find title Urticaria: Causes, symptoms, complications and prevention in name me-day.json
# Cannot find title High liver enzymes: Levels, complications and prevention in name men-gan-cao.json
# Cannot find title Metapneumovirus: Causes, targets and prevention in name metapneumovirus.json
# Cannot find title High blood fat: Causes, symptoms, diagnosis and prevention in name mo-mau-cao.json
# Cannot find title What is dense breast tissue? Causes, diagnosis, significance and risks in name mo-vu-day-dac.json
# Cannot find title Pterygium pterygium: Causes, symptoms and prevention in name mong-mat.json
# Cannot find title What is hidden acne? 3 extremely effective ways to prevent acne hidden under the skin in name mun-an.json
# Cannot find title What is cystic acne? Identification characteristics of common types today in name mun-boc.json
# Cannot find title What is acne? Causes and "favorite" growth locations in name mun-cam.json
# Cannot find title Warts on the feet soles: Causes, signs, prevention in name mun-coc-o-chan.json
# Cannot find title Warts on hands fingers: Causes, signs, treatment and prevention in name mun-coc-o-tay.json
# Cannot find title Flat warts: Causes, signs and prevention in name mun-coc-phang.json
# Cannot find title Warts: Causes, signs, diagnosis, prevention in name mun-coc.json
# Cannot find title Hormonal acne: Causes, symptoms and care in name mun-noi-tiet.json
# Cannot find title Chin acne: Causes, symptoms and prevention in name mun-trung-ca-o-cam.json
# Cannot find title Back acne: Causes, symptoms, prevention in name mun-trung-ca-o-lung.json
# Cannot find title Acne during puberty: Causes, signs, prevention in name mun-trung-ca-o-tuoi-day-thi.json
# Cannot find title Acne: Causes, symptoms and risks you need to know in name mun-trung-ca.json
# Cannot find title What is melasma? Causes of formation and notes you need to know in name nam-da.json
# Cannot find title Endocrine melasma: Causes, symptoms, diagnosis and prevention in name nam-noi-tiet.json
# Cannot find title Fungus of the external auditory canal: Causes, signs and treatments in name nam-ong-tai-ngoai.json
# Cannot find title What disease causes dizziness when lying down? Causes and treatments in name nam-xuong-bi-chong-mat.json
# Cannot find title Ovarian functional cysts: Causes, signs and treatments in name nang-co-nang-buong-trung.json
# Cannot find title Single kidney cyst: Causes, symptoms, diagnosis and treatment in name nang-don-than.json
# Cannot find title Breast cysts mammary cysts: Causes, symptoms and diagnosis in name nang-vu.json
# Cannot find title Hydrocephalus: Causes, symptoms and treatment in name nao-ung-thuy.json
# Cannot find title Hearing loss in one ear unilateral hearing loss: Causes and treatments in name nghe-kem-mot-ben-tai.json
# Cannot find title What is hearing loss? causes, signs and treatments in name nghe-kem.json
# Cannot find title Botulinum poisoning: Symptoms, causes and prevention in name ngo-doc-botulinum.json
# Cannot find title Food poisoning: Causes, symptoms and treatment instructions in name ngo-doc-thuc-pham.json
# Cannot find title Rat poison poisoning: Symptoms, diagnosis and prevention in name ngo-doc-thuoc-diet-chuot.json
# Cannot find title Ventricular extrasystole: Causes, symptoms, diagnosis, prevention in name ngoai-tam-thu-that.json
# Cannot find title Snoring: Causes, signs and prevention in name ngu-ngay.json
# Cannot find title What disease is anal itching? Causes, symptoms and prevention in name ngua-hau-mon.json
# Cannot find title Sleep apnea syndrome: Causes, symptoms and prevention in name ngung-tho-khi-ngu.json
# Cannot find title Thyroid disease: Signs, causes, diagnosis and treatment in name nhan-tuyen-giap.json
# Cannot find title Low placenta: Causes, signs, treatment and prevention in name nhau-bam-thap.json
# Cannot find title Placental abruption: Causes, signs, diagnosis, treatment in name nhau-bong-non.json
# Cannot find title Placenta previa: Classification, symptoms and diagnosis in name nhau-tien-dao.json
# Cannot find title Pork tapeworm infection: Causes, symptoms, treatment, prevention in name nhiem-au-trung-san-lon.json
# Cannot find title Urinary tract infection: Causes, symptoms, treatment in name nhiem-khuan-duong-tiet-nieu.json
# Cannot find title Helicobacter pylori infection: Signs and treatment in name nhiem-khuan-hp.json
# Cannot find title Parasitic infections: Causes, signs, diagnosis and treatment in name nhiem-ky-sinh-trung.json
# Cannot find title Ketoacidosis: Causes, symptoms and diagnosis in name nhiem-toan-ceton.json
# Cannot find title Diabetic foot infections: Causes and symptoms in name nhiem-trung-ban-chan-tieu-duong.json
# Cannot find title Intestinal infections: Symptoms, causes and prevention in name nhiem-trung-duong-ruot.json
# Cannot find title Postpartum infection: Causes, symptoms and consequences in name nhiem-trung-hau-san.json
# Cannot find title Salmonella bacterial infection: Causes, symptoms, diagnosis, prevention in name nhiem-vi-khuan-salmonella.json
# Cannot find title Atrial tachycardia: Causes, symptoms, diagnosis, prevention in name nhip-nhanh-nhi.json
# Cannot find title Ventricular tachycardia: Causes, symptoms, diagnosis, prevention in name nhip-nhanh-that.json
# Cannot find title Non-ST elevation myocardial infarction: Causes and symptoms in name nhoi-mau-co-tim-khong-st-chenh-len.json
# Cannot find title Right ventricular myocardial infarction: Causes, signs and treatments in name nhoi-mau-co-tim-that-phai.json
# Cannot find title Cerebral infarction: causes, symptoms, treatment and prevention in name nhoi-mau-nao.json
# Cannot find title Liver heat liver dysfunction: Symptoms and prevention in name nong-gan.json
# Cannot find title Moles: Causes, formation mechanism and classification in name not-ruoi.json
# Cannot find title Gynecomastia: Causes, signs, treatment and prevention in name nu-hoa-tuyen-vu.json
# Cannot find title Anal fissures: Causes, symptoms and prevention in name nut-ke-hau-mon.json
# Cannot find title Premature rupture of membranes: Causes, signs and treatments in name oi-vo-non.json
# Cannot find title Morning sickness during pregnancy: Causes, symptoms and prevention in name om-nghen-khi-mang-thai.json
# Cannot find title What is a stealth omicron? Symptoms and diagnostic methods in name omicron-tang-hinh.json
# Cannot find title Rash on chest breast: Causes, signs, treatment, prevention in name phat-ban-o-nguc.json
# Cannot find title What disease does pneumococcus cause: Causes, treatment and prevention in name phe-cau-khuan.json
# Cannot find title Prostate enlargement: Causes, symptoms and prevention in name phi-dai-tuyen-tien-liet.json
# Cannot find title Breast enlargement: Causes, symptoms and treatments in name phi-dai-tuyen-vu.json
# Cannot find title Arm lymphedema: Causes, treatment and prevention in name phu-bach-huyet-canh-tay.json
# Cannot find title Stomach polyps: Causes, symptoms and prevention in name polyp-da-day.json
# Cannot find title Colon polyps: Causes, signs and prevention in name polyp-dai-trang.json
# Cannot find title Vocal cord polyps: Causes, symptoms and treatment in name polyp-day-thanh-quan.json
# Cannot find title Anal polyps: Causes, symptoms and prevention in name polyp-hau-mon.json
# Cannot find title Rectal polyps: Causes, symptoms and prevention in name polyp-truc-trang.json
# Cannot find title Proteinuria: Causes, symptoms, diagnosis, treatment in name protein-nieu.json
# Cannot find title What disease is excessive sweating in hands and feet? Causes and symptoms in name ra-mo-hoi-tay-chan-nhieu.json
# Cannot find title Is vegetables stuck to the edges dangerous? Causes, signs, prevention in name rau-bam-mep.json
# Cannot find title Placenta accreta: Causes, symptoms, treatment and prevention in name rau-cai-rang-luoc.json
# Cannot find title Placenta praevia: Causes, signs and prevention in name rau-tien-dao.json
# Cannot find title Anal fistula – Causes, symptoms and diagnosis in name ro-hau-mon.json
# Cannot find title Atrial fistula: Causes, signs, treatment and hygiene in name ro-luan-nhi.json
# Cannot find title Congenital metabolic disorders: Causes, symptoms, treatment in name roi-loan-chuyen-hoa-bam-sinh.json
# Cannot find title Erectile dysfunction: Causes, symptoms, treatment and prevention in name roi-loan-cuong-duong.json
# Cannot find title Sleep disorders: Causes, signs, diagnosis and prevention in name roi-loan-giac-ngu.json
# Cannot find title Voice disorders: Causes, signs and treatments in name roi-loan-giong-noi.json
# Cannot find title Menstrual disorders: Causes, signs, diagnosis, prevention in name roi-loan-kinh-nguyet.json
# Cannot find title What is dyslipidemia? Causes, symptoms, prevention in name roi-loan-lipid-mau.json
# Cannot find title Generalized anxiety disorder GAD: Symptoms and causes in name roi-loan-lo-au-lan-toa.json
# Cannot find title Anxiety disorders: Causes, diagnosis and treatment methods in name roi-loan-lo-au.json
# Cannot find title Bipolar disorder: Symptoms diagnosis and treatment in name roi-loan-luong-cuc.json
# Cannot find title Bradycardia: Causes, symptoms, diagnosis and treatment in name roi-loan-nhip-cham.json
# Cannot find title Heart arrhythmia: Causes, signs and treatments in name roi-loan-nhip-tim.json
# Cannot find title Postpartum hormonal disorders: Causes and signs of recognition in name roi-loan-noi-tiet-to-sau-sinh.json
# Cannot find title Endocrine disorders: Causes, symptoms and diagnosis in name roi-loan-noi-tiet.json
# Cannot find title Dissociative disorders: Causes, signs, treatments in name roi-loan-phan-ly.json
# Cannot find title Pelvic floor disorders: Causes, signs and treatments in name roi-loan-san-chau.json
# Cannot find title Vestibular disorders: Causes, symptoms and treatments in name roi-loan-tien-dinh.json
# Cannot find title Digestive disorders: Causes, symptoms and prevention in name roi-loan-tieu-hoa.json
# Cannot find title Premenopausal menorrhagia: Causes, signs and treatments in name rong-kinh-tien-man-kinh.json
# Cannot find title Menorrhagia: Causes, signs, treatment and prevention in name rong-kinh.json
# Cannot find title Atrial fibrillation: Causes, signs and diagnosis you need to know in name rung-nhi.json
# Cannot find title What is hair loss? 15 Common causes and signs in name rung-toc.json
# Cannot find title Dementia: Causes, signs, and treatments in name sa-sut-tri-tue.json
# Cannot find title Pelvic organ prolapse: Causes, symptoms, diagnosis and treatment in name sa-tang-chau.json
# Cannot find title Testicular prolapse: Causes, symptoms and treatment in name sa-tinh-hoan.json
# Cannot find title Rectal prolapse: Pictures, signs and treatment in name sa-truc-trang.json
# Cannot find title Uterine prolapse during pregnancy: Causes, signs, treatment in name sa-tu-cung-khi-mang-thai.json
# Cannot find title Postpartum uterine prolapse: Symptoms, causes and treatments in name sa-tu-cung.json
# Cannot find title Eclampsia: Causes, symptoms, diagnosis and prevention in name san-giat.json
# Cannot find title Lung fluke disease: Signs, causes, treatment, prevention in name san-la-phoi.json
# Cannot find title Hydatid disease: Causes, symptoms, treatment and prevention in name san-lon-gao.json
# Cannot find title Keloids: Causes, symptoms and prevention in name seo-loi.json
# Cannot find title What are pitted scars? Causes, signs and classification in name seo-ro.json
# Cannot find title Premature birth: Causes, signs and how to care for your baby in name sinh-non.json
# Cannot find title Bladder stones: Causes, signs, diagnosis and treatment in name soi-bang-quang.json
# Cannot find title Gallbladder sludge: Causes, symptoms and prevention in name soi-bun-tui-mat.json
# Cannot find title Gallstones: Causes, symptoms and treatments in name soi-mat.json
# Cannot find title Ureteral stones: Causes, signs and treatments in name soi-nieu-quan.json
# Cannot find title Common bile duct stones: Causes, symptoms, diagnosis and prevention in name soi-ong-mat-chu.json
# Cannot find title Kidney stones: Causes, signs and treatments in name soi-than.json
# Cannot find title Urinary stones: Causes, symptoms, treatment and prevention in name soi-tiet-nieu.json
# Cannot find title Urinary incontinence: Causes, symptoms, treatment and prevention in name son-tieu.json
# Cannot find title Malaria: Symptoms, causes and diagnosis in name sot-ret.json
# Cannot find title Viral fever: Causes, symptoms, diagnosis and treatment in name sot-sieu-vi.json
# Cannot find title Dengue fever: Signs, causes, diagnosis and prevention in name sot-xuat-huyet.json
# Cannot find title Genital warts in women: Causes, symptoms, treatment and prevention in name sui-mao-ga-o-nu.json
# Cannot find title Genital warts: Causes, signs, complications, prevention in name sui-mao-ga.json
# Cannot find title Premature ovarian failure: Causes, signs, diagnosis and prevention in name suy-buong-trung-som.json
# Cannot find title Acute liver failure: Causes, signs, diagnosis and prevention in name suy-gan-cap.json
# Cannot find title Chronic liver failure: Causes, signs, treatment and prevention in name suy-gan-man-tinh.json
# Cannot find title Liver failure: Causes, signs and prevention in name suy-gan.json
# Cannot find title Testosterone deficiency: Causes, signs, treatments in name suy-giam-testosterone.json
# Cannot find title Varicose veins of the lower limbs: Causes, signs, treatment in name suy-gian-tinh-mach-chi-duoi.json
# Cannot find title Varicose veins of the lower extremities: Causes, symptoms and treatment in name suy-gian-tinh-mach-sau-chi-duoi.json
# Cannot find title Respiratory failure acute: Causes, diagnosis, symptoms and treatment in name suy-ho-hap.json
# Cannot find title Acute kidney failure: Causes, signs, treatment and prevention in name suy-than-cap.json
# Cannot find title Chronic kidney failure: Causes, diagnosis and treatment in name suy-than-man.json
# Cannot find title Kidney failure: Causes, signs, diagnosis and treatment in name suy-than.json
# Cannot find title End-stage heart failure: Causes, symptoms, treatment in name suy-tim-giai-doan-cuoi.json
# Cannot find title Chronic heart failure: Causes, symptoms and diagnosis in name suy-tim-man-tinh.json
# Cannot find title Decompensated heart failure: Causes, symptoms, diagnosis and treatment in name suy-tim-mat-bu.json
# Cannot find title Right heart failure: Causes, symptoms, diagnosis, treatment in name suy-tim-phai.json
# Cannot find title Congestive heart failure: Causes, symptoms, diagnosis, treatment in name suy-tim-sung-huyet.json
# Cannot find title Left heart failure: Causes, symptoms, diagnosis and treatment in name suy-tim-trai.json
# Cannot find title Heart failure: Causes, symptoms and treatments in name suy-tim.json
# Cannot find title Chronic venous insufficiency: Causes, symptoms and treatment in name suy-tinh-mach-man-tinh.json
# Cannot find title Adrenal insufficiency: Causes, signs and treatments in name suy-tuyen-thuong-than.json
# Cannot find title Cerebral vascular occlusion: Signs, causes, treatment and prevention in name tac-mach-mau-nao.json
# Cannot find title Blocked vas deferens: Causes, diagnosis and treatment in name tac-ong-dan-tinh.json
# Cannot find title Blocked milk ducts after giving birth: Causes, symptoms, diagnosis and prevention in name tac-tia-sua-sau-sinh.json
# Cannot find title Blocked fallopian tubes Blocked fallopian tubes: Causes and symptoms in name tac-voi-trung.json
# Cannot find title Stroke: Causes, symptoms and diagnosis in name tai-bien-mach-mau-nao.json
# Cannot find title Early repolarization: Causes, symptoms, diagnosis and treatment in name tai-cuc-som.json
# Cannot find title Hyperuricemia: Causes, symptoms, diagnosis and treatment in name tang-acid-uric-mau.json
# Cannot find title Pulmonary hypertension: Causes, symptoms and treatments in name tang-ap-phoi.json
# Cannot find title Gestational hypertension: Symptoms, treatment and prevention in name tang-huyet-ap-thai-ky.json
# Cannot find title Primary essential hypertension: Causes, symptoms, treatment in name tang-huyet-ap-vo-can.json
# Cannot find title Hypertension: Causes, symptoms, diagnosis, prevention in name tang-huyet-ap.json
# Cannot find title Hyperhidrosis: Causes, symptoms, treatment and prevention in name tang-tiet-mo-hoi.json
# Cannot find title Constipation: Causes, signs, dangers and treatments in name tao-bon.json
# Cannot find title Refractive errors: Causes, symptoms, diagnosis, prevention in name tat-khuc-xa.json
# Cannot find title Numbness of limbs: Causes, symptoms, treatment and prevention in name te-bi-chan-tay.json
# Cannot find title Diabetic muscular atrophy: Causes, symptoms and treatment in name teo-co-do-dai-thao-duong.json
# Cannot find title Testicular atrophy: Causes, signs, diagnosis and prevention in name teo-tinh-hoan.json
# Cannot find title What is stillbirth? Signs and causes of stillbirth in name thai-luu.json
# Cannot find title Polycystic kidney: Causes, signs, treatment, prevention in name than-da-nang.json
# Cannot find title Fibrocystic breast changes: Causes, symptoms and diagnosis in name thay-doi-soi-boc-tuyen-vu.json
# Cannot find title Chronic ischemic heart disease: Causes and treatments in name thieu-mau-co-tim-cuc-bo-man-tinh.json
# Cannot find title Myocardial ischemia: Causes, signs, complications and prevention in name thieu-mau-co-tim.json
# Cannot find title Cerebral anemia: Symptoms, causes and prevention in name thieu-mau-nao.json
# Cannot find title G6PD deficiency: Causes, signs and treatments in name thieu-men-g6pd.json
# Cannot find title Osteoarthritis of the ankle: Causes, signs, treatment, prevention in name thoai-hoa-khop-co-chan.json
# Cannot find title Osteoarthritis of the wrist: Causes, symptoms and treatment in name thoai-hoa-khop-co-tay.json
# Cannot find title Osteoarthritis: Causes, symptoms, treatment and prevention in name thoai-hoa-khop.json
# Cannot find title Hiatal hernia: Causes, symptoms, diagnosis and treatment in name thoat-vi-khe-hoanh.json
# Cannot find title Atrial septal defect: Causes, symptoms and treatment in name thong-lien-nhi.json
# Cannot find title Ventricular septal defect: Causes, symptoms and treatment in name thong-lien-that.json
# Cannot find title Excess estrogen: Signs, causes and prevention in name thua-estrogen.json
# Cannot find title Amniotic embolism amniotic embolism: Causes, signs and prevention in name thuyen-tac-oi.json
# Cannot find title Preeclampsia: Causes, signs, treatment and prevention in name tien-san-giat.json
# Cannot find title Prediabetes Prediabetes: Causes, signs in name tien-tieu-duong.json
# Cannot find title Nipple discharge clear white/cloudy: Causes and signs in name tiet-dich-num-vu.json
# Cannot find title Painful urination: Causes, symptoms, diagnosis and treatment in name tieu-buot.json
# Cannot find title Diarrhea: Causes, symptoms, treatment and prevention in name tieu-chay.json
# Cannot find title Nocturia: Causes, signs and prevention in name tieu-dem.json
# Cannot find title Diabetic itchy skin: Causes, signs and treatments in name tieu-duong-bi-ngua-da.json
# Cannot find title Type 1 diabetes: Causes, symptoms and diagnosis in name tieu-duong-tuyp-1.json
# Cannot find title Type 2 diabetes: Causes, signs and prevention in name tieu-duong-tuyp-2.json
# Cannot find title Urinary incontinence: Causes, symptoms, treatment and prevention medications in name tieu-khong-tu-chu.json
# Cannot find title Heart palpitations: Causes, symptoms, diagnosis, prevention in name tim-dap-nhanh.json
# Cannot find title Undescended testicles: Congenital disease causing high infertility in name tinh-hoan-an.json
# Cannot find title Undescended testicles: Causes, symptoms, diagnosis and treatment in name tinh-hoan-lac-cho.json
# Cannot find title Weak sperm: Causes, signs and treatments in name tinh-trung-yeu.json
# Cannot find title Postpartum depression: Causes, signs, prevention and treatment in name tram-cam-sau-sinh.json
# Cannot find title Depression: Causes, subjects and treatments in name tram-cam.json
# Cannot find title Gastroesophageal reflux: Causes and treatments in name trao-nguoc-da-day-thuc-quan.json
# Cannot find title Twin-to-twin transfusion syndrome: Causes, signs and treatment in name truyen-mau-song-thai.json
# Cannot find title Tetralogy of Fallot Fallot 4: Causes, signs and complications in name tu-chung-fallot.json
# Cannot find title What is a cerebral aneurysm? Common locations and treatments in name tui-phinh-mach-mau-nao.json
# Cannot find title Urethral diverticula: Causes, symptoms, diagnosis, treatment in name tui-thua-nieu-dao.json
# Cannot find title What disease is hemangioma? Signs, causes and diagnosis in name u-mau.json
# Cannot find title Molluscum contagiosum skin tags: Causes, signs and treatments in name u-mem-treo.json
# Cannot find title Ovarian cysts: Causes, symptoms, diagnosis and treatment in name u-nang-buong-trung.json
# Cannot find title Benign brain tumors: Signs, causes, diagnosis and treatment in name u-nao-lanh-tinh.json
# Cannot find title Brain tumor: Signs, causes and diagnosis in name u-nao.json
# Cannot find title Frontal sinus mucocele: Causes, symptoms and diagnosis in name u-nhay-xoang-tran.json
# Cannot find title What are genital papillomas? Benign or malignant? Causes and symptoms in name u-nhu-sinh-duc.json
# Cannot find title Benign kidney tumors: Causes, symptoms, diagnosis and treatment in name u-than-lanh-tinh.json
# Cannot find title Mediastinal tumor: Causes, symptoms, diagnosis and prevention in name u-trung-that.json
# Cannot find title Spinal myeloma: Symptoms, causes, diagnosis and treatment in name u-tuy-song.json
# Cannot find title What is a thyroid tumor? Signs, causes, complications and diagnosis in name u-tuyen-giap.json
# Cannot find title Parotid salivary gland tumor: Causes, signs and treatment in name u-tuyen-nuoc-bot-mang-tai.json
# Cannot find title What is a pineal tumor? Symptoms, causes and diagnosis? in name u-tuyen-tung.json
# Cannot find title Uterine fibroids during pregnancy: Causes, symptoms, treatment in name u-xo-tu-cung-khi-mang-thai.json
# Cannot find title Bone tumors: Causes, signs, diagnosis and prevention in name u-xuong.json
# Cannot find title Ductal carcinoma in situ DCIS: Symptoms and treatment in name ung-thu-bieu-mo-ong-tuyen-vu-tai-cho.json
# Cannot find title Stage 1 ovarian cancer: Symptoms, diagnosis and treatment in name ung-thu-buong-trung-giai-doan-1.json
# Cannot find title Stage 4 ovarian cancer: Symptoms, treatment and prognosis in name ung-thu-buong-trung-giai-doan-4.json
# Cannot find title Ovarian cancer: Causes, signs and diagnosis in name ung-thu-buong-trung.json
# Cannot find title Cervical cancer stage I early stage: Symptoms and treatment in name ung-thu-co-tu-cung-giai-doan-1.json
# Cannot find title Stage II cervical cancer: Signs and treatment in name ung-thu-co-tu-cung-giai-doan-2.json
# Cannot find title Late stage cervical cancer 4: Signs and treatment in name ung-thu-co-tu-cung-giai-doan-cuoi.json
# Cannot find title Cervical cancer: Causes, diagnosis and prevention in name ung-thu-co-tu-cung.json
# Cannot find title Metastatic stomach cancer: Symptoms and treatment in name ung-thu-da-day-di-can.json
# Cannot find title Late-stage stomach cancer: Symptoms and palliative treatment in name ung-thu-da-day-giai-doan-cuoi.json
# Cannot find title Stomach cancer: Signs, causes and treatment in name ung-thu-da-day.json
# Cannot find title Skin cancer: Signs, causes and diagnosis in name ung-thu-da.json
# Cannot find title Colon cancer stage 0: Don't be subjective in the pre-disease stage in name ung-thu-dai-trang-giai-doan-0.json
# Cannot find title Stage 1 colon cancer: Signs, diagnosis and treatment in name ung-thu-dai-trang-giai-doan-1.json
# Cannot find title Stage 2 colon cancer: Signs, diagnosis and treatment in name ung-thu-dai-trang-giai-doan-2.json
# Cannot find title Stage 3 colon cancer: Signs, diagnosis and treatment in name ung-thu-dai-trang-giai-doan-3.json
# Cannot find title Stage 4 colon cancer: Signs and treatment in name ung-thu-dai-trang-giai-doan-4.json
# Cannot find title Colon cancer: Causes, signs and treatment in name ung-thu-dai-trang.json
# Cannot find title Penile cancer: Causes, signs, diagnosis and prevention in name ung-thu-duong-vat.json
# Cannot find title Liver cancer: Causes, symptoms and treatment in name ung-thu-gan.json
# Cannot find title Stage I non-small cell lung cancer: Symptoms and treatment in name ung-thu-phoi-khong-te-bao-nho-giai-doan-1.json
# Cannot find title Stage II non-small cell lung cancer: Symptoms and treatment in name ung-thu-phoi-khong-te-bao-nho-giai-doan-2.json
# Cannot find title Stage III non-small cell lung cancer: Symptoms and treatment in name ung-thu-phoi-khong-te-bao-nho-giai-doan-3.json
# Cannot find title Lung cancer malignant lung tumor: Causes, signs and treatment in name ung-thu-phoi.json
# Cannot find title Kidney cancer: Causes, signs, diagnosis and treatment in name ung-thu-than.json
# Cannot find title Laryngeal cancer: Causes, symptoms and diagnosis in name ung-thu-thanh-quan.json
# Cannot find title Esophageal cancer: Causes, signs, diagnosis and prevention in name ung-thu-thuc-quan.json
# Cannot find title Testicular cancer: Signs, diagnosis and treatment in name ung-thu-tinh-hoan.json
# Cannot find title Thyroid cancer: Causes, diagnosis, common complications in name ung-thu-tuyen-giap.json
# Cannot find title Prostate cancer: Causes, signs and treatments in name ung-thu-tuyen-tien-liet.json
# Cannot find title Stage 0 nasopharyngeal cancer: Detected early, highly curable in name ung-thu-vom-hong-giai-doan-0.json
# Cannot find title Stage 1 nasopharyngeal cancer: Symptoms, diagnosis and treatment in name ung-thu-vom-hong-giai-doan-1.json
# Cannot find title Stage 2 nasopharyngeal cancer: Symptoms, diagnosis and treatment in name ung-thu-vom-hong-giai-doan-2.json
# Cannot find title Stage 3 nasopharyngeal cancer: Symptoms, diagnosis and treatment in name ung-thu-vom-hong-giai-doan-3.json
# Cannot find title Early stage nasopharyngeal cancer: Signs, diagnosis and treatment in name ung-thu-vom-hong-giai-doan-dau.json
# Cannot find title Nasopharyngeal cancer: Causes, diagnosis and prevention in name ung-thu-vom-hong.json
# Cannot find title Breast cancer stage 0: Don't be subjective in the pre-cancer stage in name ung-thu-vu-giai-doan-0.json
# Cannot find title Stage 1 breast cancer: Signs, diagnosis and treatment in name ung-thu-vu-giai-doan-1.json
# Cannot find title Stage 2 breast cancer: Symptoms, treatment and prognosis in name ung-thu-vu-giai-doan-2.json
# Cannot find title Stage 3 breast cancer: Treatment methods and prognosis in name ung-thu-vu-giai-doan-3.json
# Cannot find title Stage 4 breast cancer: Symptoms, treatment and prognosis in name ung-thu-vu-giai-doan-4.json
# Cannot find title Early stage early breast cancer: Symptoms, diagnosis and treatment in name ung-thu-vu-giai-doan-dau.json
# Cannot find title Breast cancer recurrence: Signs, causes and prevention in name ung-thu-vu-tai-phat.json
# Cannot find title Breast cancer: Signs, causes and prevention in name ung-thu-vu.json
# Cannot find title Bone cancer: Causes, signs, treatment and prevention in name ung-thu-xuong.json
# Cannot find title Chronic vaginitis: Causes, symptoms, diagnosis, treatment in name viem-am-dao-man-tinh.json
# Cannot find title Vaginitis: Causes, symptoms, diagnosis and treatment in name viem-am-dao.json
# Cannot find title Purulent tonsillitis: Causes, symptoms and treatments in name viem-amidan-hoc-mu.json
# Cannot find title Chronic tonsillitis: Causes, symptoms and prevention in name viem-amidan-man-tinh.json
# Cannot find title Tonsillitis: Causes, symptoms and treatment in name viem-amidan.json
# Cannot find title Acute cystitis: Causes, symptoms, diagnosis and prevention in name viem-bang-quang-cap.json
# Cannot find title Interstitial cystitis: Causes, symptoms and treatment in name viem-bang-quang-ke.json
# Cannot find title Chronic cystitis: Causes, symptoms, diagnosis and prevention in name viem-bang-quang-man-tinh.json
# Cannot find title Cystitis in women: Causes, symptoms and prevention in name viem-bang-quang-o-nu-gioi.json
# Cannot find title Hemorrhagic cystitis: Causes, symptoms, diagnosis, treatment in name viem-bang-quang-xuat-huyet.json
# Cannot find title Cystitis: Causes, symptoms, diagnosis and prevention in name viem-bang-quang.json
# Cannot find title Finger tenosynovitis: Causes, symptoms, treatment, prevention in name viem-bao-gan-ngon-tay.json
# Cannot find title Wrist bursitis: Causes, signs and treatments in name viem-bao-hoat-dich-co-tay.json
# Cannot find title Ankle synovitis: Causes, symptoms, treatment in name viem-bao-hoat-dich-khop-co-chan.json
# Cannot find title Knee bursitis: Causes, signs and treatment in name viem-bao-hoat-dich-khop-goi.json
# Cannot find title Hip bursitis: Causes, symptoms, treatment in name viem-bao-hoat-dich-khop-hang.json
# Cannot find title Shoulder bursitis: Causes, symptoms and treatment in name viem-bao-hoat-dich-khop-vai.json
# Cannot find title Foreskin inflammation: Causes, signs and prevention in name viem-bao-quy-dau.json
# Cannot find title Pyelonephritis: Causes, symptoms and prevention in name viem-be-than.json
# Cannot find title Blepharitis on the eyes: Causes, symptoms and prevention in name viem-bo-mi-tren-mat.json
# Cannot find title Acute glomerulonephritis: Causes, symptoms, diagnosis and prevention in name viem-cau-than-cap.json
# Cannot find title Lupus glomerulonephritis: Causes, symptoms and treatment in name viem-cau-than-lupus.json
# Cannot find title Chronic glomerulonephritis: Causes, symptoms, diagnosis and prevention in name viem-cau-than-man.json
# Cannot find title Glomerulonephritis: Causes, symptoms, treatment and prevention in name viem-cau-than.json
# Cannot find title Atopic dermatitis: Symptoms, causes, complications and prevention in name viem-da-co-dia.json
# Cannot find title Acute gastritis: Causes, symptoms, diagnosis and treatment in name viem-da-day-cap.json
# Cannot find title Gastritis: Causes, symptoms, diagnosis and treatment in name viem-da-day-ta-trang.json
# Cannot find title Gastritis: Causes, symptoms, diagnosis and prevention in name viem-da-day.json
# Cannot find title Atopic dermatitis: Causes, symptoms and prevention in name viem-da-di-ung.json
# Cannot find title Polysinusitis: Causes, symptoms and treatment in name viem-da-xoang.json
# Cannot find title Colitis: causes, symptoms and treatments in name viem-dai-trang.json
# Cannot find title Lower respiratory tract infection: Causes, signs and treatments in name viem-duong-ho-hap-duoi.json
# Cannot find title Enteritis: Symptoms, causes and prevention in name viem-duong-ruot.json
# Cannot find title Urinary tract infections during pregnancy: Causes and treatments in name viem-duong-tiet-nieu-khi-mang-thai.json
# Cannot find title Postpartum urinary tract infection: Causes and effective treatments in name viem-duong-tiet-nieu-sau-sinh.json
# Cannot find title Urinary tract infections: Causes, symptoms, diagnosis and treatment in name viem-duong-tiet-nieu.json
# Cannot find title Hepatitis A: Causes, signs and treatments in name viem-gan-a.json
# Cannot find title Hepatitis C: Causes, signs, treatment and prevention in name viem-gan-c.json
# Cannot find title Thumb flexor tendonitis: Causes, symptoms, treatment in name viem-gan-gap-ngon-tay-cai.json
# Cannot find title Achilles tendonitis: Causes, symptoms, home treatment in name viem-gan-got-chan-achilles.json
# Cannot find title Chronic hepatitis: Causes, symptoms, diagnosis and prevention in name viem-gan-man-tinh.json
# Cannot find title Autoimmune hepatitis: Causes, signs, diagnosis and prevention in name viem-gan-tu-mien.json
# Cannot find title Gastritis antrum: Causes, symptoms and prevention in name viem-hang-vi-da-day.json
# Cannot find title Anal inflammation: Causes, symptoms and prevention in name viem-hau-mon.json
# Cannot find title Granulomatous pharyngitis: Causes, signs, prevention and treatment in name viem-hong-hat.json
# Cannot find title Congestive pharyngitis: Causes, signs, prevention and treatment in name viem-hong-xung-huyet.json
# Cannot find title Conjunctivitis: Causes, symptoms and prevention in name viem-ket-mac.json
# Cannot find title Acute arthritis: Causes, signs, treatment, prevention in name viem-khop-cap.json
# Cannot find title Wrist arthritis: Causes, symptoms, treatment and prevention in name viem-khop-co-tay.json
# Cannot find title Streptococcal arthritis: Causes, signs, treatment and prevention in name viem-khop-lien-cau.json
# Cannot find title Finger arthritis: Causes, signs, treatment and prevention in name viem-khop-ngon-tay.json
# Cannot find title Septic arthritis: Causes, signs, treatment, prevention in name viem-khop-nhiem-khuan.json
# Cannot find title Reactive arthritis: Causes, symptoms, treatment and prevention in name viem-khop-phan-ung.json
# Cannot find title Psoriatic arthritis: Causes, symptoms, treatment and prevention in name viem-khop-vay-nen.json
# Cannot find title Arthritis: Causes, symptoms, treatment and prevention in name viem-khop.json
# Cannot find title Peptic ulcer disease: Causes, symptoms and diagnosis in name viem-loet-da-day-ta-trang.json
# Cannot find title Corneal ulcers: Causes, symptoms and prevention in name viem-loet-giac-mac.json
# Cannot find title Uveitis: Causes, symptoms and treatments in name viem-mang-bo-dao.json
# Cannot find title Meningococcal meningitis: Signs, causes, diagnosis, treatment in name viem-mang-nao-mo-cau.json
# Cannot find title Purulent meningitis: Signs, causes, diagnosis and treatment in name viem-mang-nao-mu.json
# Cannot find title Meningitis: Signs, causes, complications and diagnosis in name viem-mang-nao.json
# Cannot find title Epididymitis: Causes, symptoms, diagnosis and prevention in name viem-mao-tinh-hoan.json
# Cannot find title Iritis of the ciliary body: Causes, symptoms and treatment in name viem-mong-mat.json
# Cannot find title Seasonal allergic rhinitis: Causes, signs and treatments in name viem-mui-di-ung-thoi-tiet.json
# Cannot find title Allergic rhinitis: Causes, signs and diagnosis in name viem-mui-di-ung.json
# Cannot find title Chronic rhinitis: Causes, symptoms, treatment and prevention in name viem-mui-man-tinh.json
# Cannot find title Rhinitis: Signs, classification, treatment and prevention in name viem-mui.json
# Cannot find title Gastric mucosal inflammation: Causes, symptoms and treatments in name viem-niem-mac-da-day.json
# Cannot find title Urethritis: Causes, symptoms and treatment in name viem-nieu-dao.json
# Cannot find title Endometritis: Causes, signs, diagnosis, prevention in name viem-noi-mac-tu-cung.json
# Cannot find title Chronic bronchitis: Causes, symptoms and prevention in name viem-phe-quan-man-tinh.json
# Cannot find title Bronchopneumonia: Causes, complications and prevention in name viem-phe-quan-phoi.json
# Cannot find title Metapneumovirus pneumonia: Causes, signs and treatment in name viem-phoi-do-metapneumovirus.json
# Cannot find title Pneumonia: Causes, signs, diagnosis and treatment in name viem-phoi.json
# Cannot find title Chronic enteritis: Causes, symptoms and treatment in name viem-ruot-man-tinh.json
# Cannot find title Acute appendicitis: Causes, signs and prevention in name viem-ruot-thua-cap.json
# Cannot find title Appendicitis: Causes, signs and prevention in name viem-ruot-thua.json
# Cannot find title Otitis media with perforated eardrum: Is it dangerous and how to treat it? in name viem-tai-giua-thung-mang-nhi.json
# Cannot find title Otitis media with effusion: Causes, symptoms and treatment in name viem-tai-giua-u-dich.json
# Cannot find title Purulent otitis media: Causes, signs, treatment and prevention in name viem-tai-giua-u-mu.json
# Cannot find title Otitis media – causes, signs and treatments in name viem-tai-giua.json
# Cannot find title Otitis externa: Causes, symptoms, treatment and prevention in name viem-tai-ngoai.json
# Cannot find title Mastoid otitis: Symptoms, complications, diagnosis and treatment in name viem-tai-xuong-chum.json
# Cannot find title Ear infections: Causes, symptoms, treatment and prevention in name viem-tai.json
# Cannot find title Acute pyelonephritis: Causes and treatment in name viem-than-be-than-cap.json
# Cannot find title Lupus nephritis: Causes, symptoms, diagnosis, prevention in name viem-than-lupus.json
# Cannot find title Laryngitis: Causes, complications and treatments in name viem-thanh-quan.json
# Cannot find title Orchitis: Causes, signs, diagnosis and prevention in name viem-tinh-hoan.json
# Cannot find title Proctitis: Causes, symptoms and prevention in name viem-truc-trang.json
# Cannot find title Cholecystitis: Causes, symptoms, diagnosis and prevention in name viem-tui-mat.json
# Cannot find title Chronic pancreatitis: Symptoms, causes, complications and prevention in name viem-tuy-man-tinh.json
# Cannot find title Pancreatitis: Causes, signs, complications, diagnosis and treatment in name viem-tuy.json
# Cannot find title Thyroiditis: Symptoms, causes and treatment in name viem-tuyen-giap-trieu-chung-nguyen-nhan-va-dieu-tri.json
# Cannot find title Salivary gland inflammation: Symptoms, causes and treatments in name viem-tuyen-nuoc-bot.json
# Cannot find title Acute prostatitis: Causes, symptoms and diagnosis in name viem-tuyen-tien-liet-cap-tinh.json
# Cannot find title Chronic prostatitis: Classification, causes & prevention in name viem-tuyen-tien-liet-man-tinh.json
# Cannot find title Prostatitis: Causes, signs and diagnosis in name viem-tuyen-tien-liet.json
# Cannot find title Mastitis: Causes, signs, diagnosis and prevention in name viem-tuyen-vu.json
# Cannot find title Sphenoid sinusitis: Causes, symptoms and treatment in name viem-xoang-buom.json
# Cannot find title Acute sinusitis: Causes, symptoms and treatment in name viem-xoang-cap-tinh.json
# Cannot find title Fungal sinusitis: Causes, symptoms and treatment in name viem-xoang-do-nam.json
# Cannot find title Maxillary sinusitis: Causes, signs, treatment and prevention in name viem-xoang-ham.json
# Cannot find title Chronic sinusitis: Causes, symptoms and prevention in name viem-xoang-man-tinh.json
# Cannot find title Allergic sinusitis: Causes, symptoms and treatment in name viem-xoang-mui-di-ung.json
# Cannot find title Ethmoid sinusitis: Causes, symptoms, location and prevention in name viem-xoang-sang.json
# Cannot find title Frontal sinusitis: Causes, symptoms, treatment and prevention in name viem-xoang-tran.json
# Cannot find title Gastric antrum congestion: Causes, symptoms and prevention in name viem-xung-huyet-hang-vi-da-day.json
# Cannot find title Rupture of blood vessels in the brain: Signs, causes, diagnosis and treatment in name vo-mach-mau-nao.json
# Cannot find title What is infertility? Causes, signs and treatments in name vo-sinh-hiem-muon.json
# Cannot find title Primary infertility: Causes, symptoms, diagnosis and treatment in name vo-sinh-nguyen-phat.json
# Cannot find title Female infertility: Causes, diagnosis and prevention in name vo-sinh-nu.json
# Cannot find title Infertility: Causes, symptoms and treatments in name vo-sinh.json
# Cannot find title Uterine rupture: Causes, symptoms, diagnosis and prevention in name vo-tu-cung.json
# Cannot find title Cosmetic silicon breast implant rupture: causes, signs and treatment in name vo-tui-nguc.json
# Cannot find title Bone calcification: Causes, signs, treatment and prevention in name voi-hoa-xuong.json
# Cannot find title Vertebral collapse: Causes, symptoms, treatment and prevention in name xep-dot-song.json
# Cannot find title Localized scleroderma: Causes, signs, treatment, prevention in name xo-cung-bi-khu-tru.json
# Cannot find title What is systemic scleroderma? Causes, symptoms and treatment in name xo-cung-bi-toan-the.json
# Cannot find title Scleroderma: Causes, symptoms, diagnosis and treatment in name xo-cung-bi.json
# Cannot find title Cirrhosis ascites: Causes, symptoms, diagnosis, prevention in name xo-gan-co-truong.json
# Cannot find title Compensated cirrhosis: Symptoms, diagnosis and treatment in name xo-gan-con-bu.json
# Cannot find title Alcoholic cirrhosis: Symptoms, treatment and prevention in name xo-gan-do-ruou.json
# Cannot find title Decompensated cirrhosis: Causes, symptoms and treatment in name xo-gan-mat-bu.json
# Cannot find title Cirrhosis: Causes, symptoms, diagnosis and treatment of the disease in name xo-gan.json
# Cannot find title Pulmonary fibrosis: Causes, symptoms, treatment and prevention in name xo-phoi.json
# Cannot find title Coronary atherosclerosis: Causes, symptoms, diagnosis, treatment in name xo-vua-dong-mach-vanh.json
# Cannot find title Atherosclerosis blood vessels: Causes and symptoms in name xo-vua-dong-mach.json
# Cannot find title Testicular torsion: Causes, symptoms, diagnosis, treatment in name xoan-tinh-hoan.json
# Cannot find title Gastric stomach bleeding: Causes, symptoms and prevention in name xuat-huyet-da-day.json
# Cannot find title Gastrointestinal bleeding: Causes, symptoms, treatment, prevention in name xuat-huyet-tieu-hoa.json
# Cannot find title Abnormal uterine bleeding: Causes, diagnosis and treatment in name xuat-huyet-tu-cung-bat-thuong.json
# Cannot find title Retrograde ejaculation: Overview, causes and treatments in name xuat-tinh-nguoc-dong.json
# Cannot find title Premature ejaculation: Causes, signs and treatments in name xuat-tinh-som.json
# Cannot find title Erectile dysfunction in women: Causes, symptoms and ways to improve in name yeu-sinh-ly-o-nu.json
# Cannot find title What is erectile dysfunction? Causes, symptoms and treatment in name yeu-sinh-ly.json
# num_subsections: 4993
